# %% [markdown]
# ## **Intervlo de confiança - Desvio padrão populacional desconhecido**
#
# Você seleciona aleatoriamente 16 cafeterias de uma grnade rede e mede a temperatura do café vendido em cada uma delas. A temperatura média da amostra é de 162,0 ºF (Fahrenheit), com um desvio padrão amostral de 10,0 ºF. Construa um intervalo de confiança de 95% para a temperatura média da população de cafés vendidos. Suponha que as temperaturas tenham uma distribuição aproximadamente normal.
#
#
# **Dados conhecidos:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculo de erro padrao tc (T crítico) = 2.1314
erro_padrao = 2.1314 * (10/16**0.5)

# Limite superior e inferior para 95% de confiança
limite_inferior = 162 - erro_padrao
limite_superior = 162 + erro_padrao

print("-------------------------------")

print("Limite inferior",limite_inferior)
print("Limite superior",limite_superior)

print("-------------------------------")
print(f"Com 95% de confiança a temperatura média dos cafés dessa rede de cafeterias está entre {'{:.2f}ºF'.format(limite_inferior)} e {'{:.2f}ºF'.format(limite_superior)}")
print("-------------------------------")
# Out:
# -------------------------------
# Limite inferior 156.6715
# Limite superior 167.3285
# -------------------------------
# Com 95% de confiança a temperatura média dos cafés dessa rede de cafeterias está entre 156.67ºF e 167.33ºF
# -------------------------------
